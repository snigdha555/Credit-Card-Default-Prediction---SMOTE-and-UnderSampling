# %%
import pandas as pd

df = pd.read_excel('default_credit.xls')
df.head(5)
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ...

# %%
#importing classification libraries

from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression

from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier

from sklearn.preprocessing import RobustScaler

from sklearn.metrics import confusion_matrix

from sklearn.metrics import classification_report

from sklearn.metrics import accuracy_score, make_scorer

# %%
df = df.rename(columns={'default payment next month': 'DEFAULT','PAY_0': 'PAY_1'})

df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# 0         0         0         0        1
# ...

# %%
df1 = df.drop('ID', axis = 1)

df1.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0     -2  ...          0          0          0         0       689         0
# 1      0  ...       3272       3455       3261         0      1000      1000
# 2      0  ...      14331      14948      15549      1518      1500      1000
# 3      0  ...      28314      28959      29547      2000      2019      1200
# 4      0  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# ...

# %%
X = df1.drop('DEFAULT', axis = 1)

y = df1['DEFAULT']

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.20,
    random_state=4)

scaler = RobustScaler()

normalized_x_train = pd.DataFrame(
    scaler.fit_transform(x_train),
    columns = x_train.columns
)

LR = LogisticRegression(
    C=0.01,
    solver='liblinear'
).fit(normalized_x_train, y_train)

normalized_x_test = pd.DataFrame(
    scaler.transform(x_test),
    columns = x_test.columns
)
y_test_pred = LR.predict(normalized_x_test)
print('Accuracy:', accuracy_score(y_test,y_test_pred))
# Out:
# Accuracy: 0.8011666666666667

# %%
df_train = pd.concat([x_train,y_train],axis = 1)

df_train.head()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 15659     120000    2          3         1   37     -2     -2     -2     -2
# 12751     500000    1          1         2   29      0      0      0      0
# 27300     150000    1          2         1   48      0      0      0      0
# 18339      20000    2          6         2   22      0      0      0      0
# 16076     100000    2          2         1   42      0      0      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 15659     -2  ...          0          0      10614       448         0
# 12751      0  ...     345238     274743     250930     30483     15773
# 27300      0  ...      66902      68230      69661      4955      4947
# 18339      0  ...       1434        500          0      4641      1019
# 16076      0  ...      10002       9804       9626      1140      1164
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# ...

# %%
ind = df_train[df_train.DEFAULT==1].index

print(len(ind))
# Out:
# 5274

# %%
ind1 = df_train[df_train.DEFAULT==0].index

print(len(ind1))
# Out:
# 18726

# %%
df_minority = df_train.loc[ind]

df_minority.shape
# Out:
# (5274, 24)

# %%
df_majority = df_train.loc[ind1]

print(df_majority.shape)

df_majority.head()
# Out:
# (18726, 24)
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 15659     120000    2          3         1   37     -2     -2     -2     -2
# 12751     500000    1          1         2   29      0      0      0      0
# 27300     150000    1          2         1   48      0      0      0      0
# 16076     100000    2          2         1   42      0      0      0      0
# 24123      50000    1          1         2   29     -1     -1     -1     -1
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 15659     -2  ...          0          0      10614       448         0
# 12751      0  ...     345238     274743     250930     30483     15773
# 27300      0  ...      66902      68230      69661      4955      4947
# 16076      0  ...      10002       9804       9626      1140      1164
# 24123     -1  ...        360        360        360       360       360
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# ...

# %%
df_maj_undersampled = df_majority.sample(n=len(ind),random_state = 123)

# %%
print(df_maj_undersampled.shape)

df_maj_undersampled.head()
# Out:
# (5274, 24)
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 1079      400000    2          3         1   39      1     -1     -1     -1
# 9683      440000    1          2         2   29      0      0      0      0
# 29834      30000    1          2         2   34      0      0      0      0
# 4881      100000    2          1         2   27      0      0      0      0
# 4323      500000    1          2         2   31      2      2      2      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 1079      -2  ...       -203       2371       1949      3603       471
# 9683       0  ...     289341     287809     293176     18887     12076
# 29834      0  ...      20929      21280      21724      2000      2000
# 4881       0  ...      79111      79993      81279      3000      3400
# 4323       0  ...     305875      46420      14540      3089     14000
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  DEFAULT
# ...

# %%
#merging minority and downsampled dataframes

df_undersampled = pd.concat([df_maj_undersampled,df_minority],axis =0)

# %%
#shuffling the dataset

from sklearn.utils import shuffle

df_undersampled = shuffle(df_undersampled)

df_undersampled.head()

df_undersampled.shape
# Out:
# (10548, 24)

# %%
#new X_train and y_train for downsampled

X_trainNew = df_undersampled.drop('DEFAULT', axis = 1)

y_trainNew = df_undersampled['DEFAULT']

# %%
scaler = RobustScaler()

normalized_x_train_us = pd.DataFrame(
    scaler.fit_transform(X_trainNew),
    columns = X_trainNew.columns
)

LR_us = LogisticRegression(
    C=0.01,
    solver='liblinear'
).fit(normalized_x_train_us, y_trainNew)


y_test_pred_us = LR_us.predict(normalized_x_test)
print('Accuracy:', accuracy_score(y_test,y_test_pred_us))
# Out:
# Accuracy: 0.658

# %%
from sklearn.ensemble import RandomForestClassifier

RF_us = RandomForestClassifier().fit(normalized_x_train_us, y_trainNew)


y_test_pred_us_RF = RF_us.predict(normalized_x_test)
print('Accuracy:', accuracy_score(y_test,y_test_pred_us_RF))
# Out:
# Accuracy: 0.7238333333333333

# %%
print(classification_report(y_test,y_test_pred_us))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.66      0.75      4638
#            1       0.36      0.65      0.46      1362
#
#     accuracy                           0.66      6000
#    macro avg       0.61      0.66      0.61      6000
# weighted avg       0.75      0.66      0.68      6000

# %%
print(classification_report(y_test,y_test_pred_us_RF))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.74      0.81      4638
#            1       0.43      0.67      0.52      1362
#
#     accuracy                           0.72      6000
#    macro avg       0.66      0.70      0.66      6000
# weighted avg       0.78      0.72      0.74      6000
